# %%
import numpy as np
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import Flatten
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.utils import np_utils
from keras import backend as K 
import matplotlib.pyplot as plt
plt.style.use('ggplot')
K.set_image_dim_ordering('th')

# %%
seed = 7
np.random.seed(seed)

# %%
# load data
(X_train, y_train), (X_test, y_test) = mnist.load_data()
# reshape to be [samples][pixels][width][height]
X_train = X_train.reshape(X_train.shape[0], 1, 28, 28).astype('float32')
X_test = X_test.reshape(X_test.shape[0], 1, 28, 28).astype('float32')

# %%
# normalize inputs from 0-255 to 0-1
X_train = X_train / 255
X_test = X_test / 255
# one hot encode outputs
y_train = np_utils.to_categorical(y_train)
y_test = np_utils.to_categorical(y_test)
num_classes = y_test.shape[1]

# %%
def baseline_model():
	# create model
	model = Sequential()
	model.add(Conv2D(32, (5, 5), input_shape=(1, 28, 28), activation='relu'))
	model.add(MaxPooling2D(pool_size=(2, 2)))
	model.add(Dropout(0.2))
	model.add(Flatten())
	model.add(Dense(128, activation='relu'))
	model.add(Dense(num_classes, activation='softmax'))
	# Compile model
	model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
	return model

# %%
# build the model
model = baseline_model()
# Fit the model
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10, batch_size=200, verbose=2)
# Final evaluation of the model
scores = model.evaluate(X_test, y_test, verbose=0)
print("Baseline Error: %.2f%%" % (100-scores[1]*100))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/10
# 3s - loss: 0.2371 - acc: 0.9313 - val_loss: 0.0818 - val_acc: 0.9752
# Epoch 2/10
# 3s - loss: 0.0720 - acc: 0.9787 - val_loss: 0.0451 - val_acc: 0.9853
# Epoch 3/10
# 3s - loss: 0.0513 - acc: 0.9845 - val_loss: 0.0460 - val_acc: 0.9855
# Epoch 4/10
# 3s - loss: 0.0410 - acc: 0.9873 - val_loss: 0.0398 - val_acc: 0.9876
# Epoch 5/10
# 4s - loss: 0.0330 - acc: 0.9896 - val_loss: 0.0332 - val_acc: 0.9883
# Epoch 6/10
# 3s - loss: 0.0269 - acc: 0.9914 - val_loss: 0.0315 - val_acc: 0.9905
# Epoch 7/10
# 3s - loss: 0.0230 - acc: 0.9926 - val_loss: 0.0335 - val_acc: 0.9888
# Epoch 8/10
# 3s - loss: 0.0199 - acc: 0.9938 - val_loss: 0.0321 - val_acc: 0.9896
# Epoch 9/10
# 3s - loss: 0.0166 - acc: 0.9949 - val_loss: 0.0290 - val_acc: 0.9899
# Epoch 10/10
# 3s - loss: 0.0140 - acc: 0.9955 - val_loss: 0.0308 - val_acc: 0.9893
# Baseline Error: 1.07%

# %%
print(history.history.keys())
# Out:
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train','test'], loc='upper left')
plt.savefig('ten-conv-epoch.jpg')
plt.show()

# %%
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train','test'],loc='upper left')
plt.savefig('ten-conv-epoch-acc.jpg')
plt.show()

# %%
# build the model
model = baseline_model()
# Fit the model
history2 = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50, batch_size=200, verbose=2)
# Final evaluation of the model
scores = model.evaluate(X_test, y_test, verbose=0)
print("Baseline Error: %.2f%%" % (100-scores[1]*100))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/50
# 3s - loss: 0.2544 - acc: 0.9272 - val_loss: 0.0846 - val_acc: 0.9754
# Epoch 2/50
# 3s - loss: 0.0741 - acc: 0.9777 - val_loss: 0.0568 - val_acc: 0.9813
# Epoch 3/50
# 3s - loss: 0.0521 - acc: 0.9842 - val_loss: 0.0467 - val_acc: 0.9853
# Epoch 4/50
# 3s - loss: 0.0400 - acc: 0.9876 - val_loss: 0.0363 - val_acc: 0.9877
# Epoch 5/50
# 3s - loss: 0.0329 - acc: 0.9895 - val_loss: 0.0348 - val_acc: 0.9877
# Epoch 6/50
# 3s - loss: 0.0281 - acc: 0.9912 - val_loss: 0.0360 - val_acc: 0.9883
# Epoch 7/50
# 3s - loss: 0.0232 - acc: 0.9922 - val_loss: 0.0329 - val_acc: 0.9889
# Epoch 8/50
# 3s - loss: 0.0185 - acc: 0.9943 - val_loss: 0.0365 - val_acc: 0.9892
# Epoch 9/50
# 3s - loss: 0.0171 - acc: 0.9944 - val_loss: 0.0308 - val_acc: 0.9900
# Epoch 10/50
# 3s - loss: 0.0142 - acc: 0.9956 - val_loss: 0.0309 - val_acc: 0.9899
# Epoch 11/50
# 3s - loss: 0.0123 - acc: 0.9961 - val_loss: 0.0360 - val_acc: 0.9891
# Epoch 12/50
# ...

# %%
plt.plot(history2.history['loss'])
plt.plot(history2.history['val_loss'])
plt.title('model loss - 50')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train','test'], loc='upper left')
plt.savefig('50-conv-epoch.jpg')
plt.show()

# %%
plt.plot(history2.history['acc'])
plt.plot(history2.history['val_acc'])
plt.title('model accuracy - 50')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train','test'],loc='upper left')
plt.savefig('fifty-conv-epoch-acc.jpg')
plt.show()
